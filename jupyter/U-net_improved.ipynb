# %% [markdown]
# # Ultrasound Nerve Segmentation
#
# ## Identify nerve structures in ultrasound images of the neck
#
# <https://www.kaggle.com/c/ultrasound-nerve-segmentation>
#
# > Even the bravest patient cringes at the mention of a surgical procedure. Surgery inevitably brings discomfort, and oftentimes involves significant post-surgical pain. Currently, patient pain is frequently managed through the use of narcotics that bring a bevy of unwanted side effects.
# This competition's sponsor is working to improve pain management through the use of indwelling catheters that block or mitigate pain at the source. Pain management catheters reduce dependence on narcotics and speed up patient recovery.
# **Accurately identifying nerve structures in ultrasound images is a critical step in effectively inserting a patient’s pain management catheter.** In this competition, Kagglers are challenged to build a model that can identify nerve structures in a dataset of ultrasound images of the neck. Doing so would improve catheter placement and contribute to a more pain free future.

# %% [markdown]
# Partially based on:
#
# * <https://github.com/jocicmarko/ultrasound-nerve-segmentation>
# * <https://github.com/EdwardTyantov/ultrasound-nerve-segmentation>
# * https://www.slideshare.net/Eduardyantov/ultrasound-segmentation-kaggle-review

# %% [markdown]
# ## Data

# %%
import os
import numpy as np
from skimage.io import imsave, imread
from tqdm import tqdm_notebook
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# The original images are 420x580.

# %%
data_path = '../raw/'

image_rows = 420
image_cols = 580

# %% [markdown]
# ### Load the training images

# %%
train_data_path = os.path.join(data_path, 'train')
images = os.listdir(train_data_path)
total = len(images) // 2

# %%
train_imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
train_imgs_mask = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)

i = 0
for image_name in tqdm_notebook(images):    
    if 'mask' in image_name:
        continue
        
    image_mask_name = image_name.split('.')[0] + '_mask.tif'
    img = imread(os.path.join(train_data_path, image_name), as_grey=True)
    img_mask = imread(os.path.join(train_data_path, image_mask_name), as_grey=True)

    img = np.array([img])
    img_mask = np.array([img_mask])

    train_imgs[i] = img
    train_imgs_mask[i] = img_mask
    i += 1
# Out:
# ...
# /home/alexej/tensorflow/lib/python3.5/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)

# %% [markdown]
# Save/load to save time when rerunning this notebook.

# %%
np.save('imgs_train.npy', train_imgs)
np.save('imgs_mask_train.npy', train_imgs_mask)

# %%
train_imgs = np.load('imgs_train.npy')
train_imgs_mask = np.load('imgs_mask_train.npy')

# %% [markdown]
# #### Let's look at some of the training images and masks

# %%
def plot_n(datasets, headers, n, width=10, height=40):
    """Plot the images alongside their masks
    
    datasets -- a tuple of numpy ndarrays
    (e.g., one array for the original images,
    one array for true masks, and one array for the predicted masks)
    headers -- a tuple containing a header for each dataset
    n -- how many sets of images-with-masks to plot
    """
    
    n_cols = len(datasets)
    f = plt.figure(figsize=(width, height))
    
    for i in range(n):
        j = 1
        for header, imgs in zip(headers, datasets):
            sp = f.add_subplot(n, n_cols, n_cols*i+j)
            sp.axis('Off')
            sp.set_title(header)
            imgs = np.squeeze(imgs)
            plt.imshow(imgs[i, :, :], cmap="gray")
            j += 1

# %%
plot_n((train_imgs, train_imgs_mask), ('US image', 'Nerve mask'), 4, width=12, height=18)

# %% [markdown]
# ### Train-validation split

# %%
np.random.seed(2018)
train_size = int(0.8 * train_imgs.shape[0])
train_ind = np.random.choice(train_imgs.shape[0], size=train_size, replace=False)
train_split = np.zeros(train_imgs.shape[0])
train_split[train_ind] = 1

imgs_train = train_imgs[train_split == 1, :, :]
imgs_val = train_imgs[train_split == 0, :, :]
imgs_mask_train = train_imgs_mask[train_split == 1, :, :]
imgs_mask_val = train_imgs_mask[train_split == 0, :, :]

print('Images:')
print('Full data: {}'.format(train_imgs.shape))
print('Training set: {}'.format(imgs_train.shape))
print('Validation set: {}'.format(imgs_val.shape))
print('Masks:')
print('Full data: {}'.format(train_imgs_mask.shape))
print('Training set: {}'.format(imgs_mask_train.shape))
print('Validation set: {}'.format(imgs_mask_val.shape))
# Out:
# Images:
# Full data: (5635, 420, 580)
# Training set: (4508, 420, 580)
# Validation set: (1127, 420, 580)
# Masks:
# Full data: (5635, 420, 580)
# Training set: (4508, 420, 580)
# Validation set: (1127, 420, 580)

# %% [markdown]
# ## Training a deep neural network

# %%
from skimage.transform import resize
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint
from keras import backend as K

K.set_image_data_format('channels_last')  # TF dimension ordering in this code
# Out:
# /home/alexej/tensorflow/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# Evaluation metric is the Dice coefficient.

# %%
def dice_coef(y_true, y_pred, smooth=1.0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)


def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# %% [markdown]
# We resize, center, and scale the images before training.

# %%
resized_img_rows = 80
resized_img_cols = 112

def preprocess(imgs, img_rows=None, img_cols=None):
    imgs_p = np.ndarray((imgs.shape[0], img_rows, img_cols), dtype=np.uint8)
    for i in range(imgs.shape[0]):
        imgs_p[i] = resize(imgs[i], (img_rows, img_cols), preserve_range=True)

    imgs_p = imgs_p[..., np.newaxis]
    return imgs_p


imgs_train = preprocess(imgs_train, img_rows=resized_img_rows, img_cols=resized_img_cols)
imgs_mask_train = preprocess(imgs_mask_train, img_rows=resized_img_rows, img_cols=resized_img_cols)
imgs_val = preprocess(imgs_val, img_rows=resized_img_rows, img_cols=resized_img_cols)
imgs_mask_val = preprocess(imgs_mask_val, img_rows=resized_img_rows, img_cols=resized_img_cols)

imgs_train = imgs_train.astype('float32')
imgs_val = imgs_val.astype('float32')

mean_train = np.mean(imgs_train)  # mean for data centering
std_train = np.std(imgs_train)  # std for data normalization

imgs_train -= mean_train
imgs_train /= std_train
imgs_mask_train = imgs_mask_train.astype('float32')
imgs_mask_train /= 255.  # scale masks to [0, 1]

imgs_val -= mean_train
imgs_val /= std_train
imgs_mask_val = imgs_mask_val.astype('float32')
imgs_mask_val /= 255.  # scale masks to [0, 1]

print('Images:')
print('Full data: {}'.format(train_imgs.shape))
print('Training set: {}'.format(imgs_train.shape))
print('Validation set: {}'.format(imgs_val.shape))
print('Masks:')
print('Full data: {}'.format(train_imgs_mask.shape))
print('Training set: {}'.format(imgs_mask_train.shape))
print('Validation set: {}'.format(imgs_mask_val.shape))
# Out:
# /home/alexej/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Images:
# Full data: (5635, 420, 580)
# Training set: (4508, 80, 112, 1)
# Validation set: (1127, 80, 112, 1)
# Masks:
# Full data: (5635, 420, 580)
# Training set: (4508, 80, 112, 1)
# Validation set: (1127, 80, 112, 1)

# %% [markdown]
# ### U-Net

# %% [markdown]
# ![U-net diagram](../img/u-net-architecture.png)

# %%
inputs = Input((resized_img_rows, resized_img_cols, 1))
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

model = Model(inputs=[inputs], outputs=[conv10])

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 80, 112, 1)   0
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 80, 112, 32)  320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 80, 112, 32)  9248        conv2d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 40, 56, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 40, 56, 64)   18496       max_pooling2d_5[0][0]
# ...

# %%
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss)

model_checkpoint = ModelCheckpoint('weights.h5', monitor='val_loss', save_best_only=True)

model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=50, verbose=1, shuffle=True,
          validation_data=(imgs_val, imgs_mask_val), callbacks=[model_checkpoint])
# Out:
# Train on 4508 samples, validate on 1127 samples
# Epoch 1/50
# 4508/4508 [==============================] - 10s 2ms/step - loss: -0.0245 - val_loss: -0.0244
# Epoch 2/50
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.0327 - val_loss: -0.0934
# Epoch 3/50
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.2028 - val_loss: -0.2664
# Epoch 4/50
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.2504 - val_loss: -0.2727
# Epoch 5/50
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.3108 - val_loss: -0.3557
# Epoch 6/50
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.3563 - val_loss: -0.3712
# Epoch 7/50
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.3841 - val_loss: -0.3620
# Epoch 8/50
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.4195 - val_loss: -0.4301
# Epoch 9/50
# ...

# %%
model.compile(optimizer=Adam(lr=1e-6), loss=dice_coef_loss)

model_checkpoint_2 = ModelCheckpoint('weights_2.h5', monitor='val_loss', save_best_only=True)

model.fit(imgs_train, imgs_mask_train, batch_size=32, epochs=20, verbose=1, shuffle=True,
          validation_data=(imgs_val, imgs_mask_val), callbacks=[model_checkpoint_2])
# Out:
# Train on 4508 samples, validate on 1127 samples
# Epoch 1/20
# 4508/4508 [==============================] - 10s 2ms/step - loss: -0.6868 - val_loss: -0.5988
# Epoch 2/20
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.6891 - val_loss: -0.5954
# Epoch 3/20
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.6866 - val_loss: -0.5992
# Epoch 4/20
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.6884 - val_loss: -0.5957
# Epoch 5/20
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.6918 - val_loss: -0.5995
# Epoch 6/20
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.6918 - val_loss: -0.5974
# Epoch 7/20
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.6915 - val_loss: -0.5975
# Epoch 8/20
# 4508/4508 [==============================] - 9s 2ms/step - loss: -0.6912 - val_loss: -0.5976
# Epoch 9/20
# ...

# %% [markdown]
# ### Some visual inspection of the results

# %% [markdown]
# #### On the training dataset

# %%
imgs_mask_pred_train = model.predict(imgs_train, verbose=1)
# Out:
# 4508/4508 [==============================] - 3s 687us/step

# %%
plot_n((imgs_train, imgs_mask_train, imgs_mask_pred_train),
       ('US image', 'True mask', 'Predicted mask'), 10, width=12, height=40)

# %% [markdown]
# #### On the validation dataset

# %%
imgs_mask_pred_val = model.predict(imgs_val, verbose=1)
# Out:
# 1127/1127 [==============================] - 1s 645us/step

# %%
plot_n((imgs_val, imgs_mask_val, imgs_mask_pred_val),
       ('US image', 'True mask', 'Predicted mask'), 10, width=12, height=40)

# %% [markdown]
# ## Test data

# %% [markdown]
# ### Load the test images

# %%
test_data_path = os.path.join(data_path, 'test')
images = os.listdir(test_data_path)
total = len(images)

test_imgs = np.ndarray((total, image_rows, image_cols), dtype=np.uint8)
test_imgs_id = np.ndarray((total, ), dtype=np.int32)

i = 0
for image_name in tqdm_notebook(images):
    img_id = int(image_name.split('.')[0])
    img = imread(os.path.join(test_data_path, image_name), as_grey=True)

    img = np.array([img])

    test_imgs[i] = img
    test_imgs_id[i] = img_id
    i += 1
# Out:
# ...
# /home/alexej/tensorflow/lib/python3.5/site-packages/skimage/external/tifffile/tifffile.py:2611: RuntimeWarning: py_decodelzw encountered unexpected end of stream
#   strip = decompress(strip)

# %% [markdown]
# Save/load to save time when rerunning this notebook.

# %%
np.save('imgs_test.npy', test_imgs)
np.save('imgs_test_id.npy', test_imgs_id)

# %%
test_imgs = np.load('imgs_test.npy')
test_imgs_id = np.load('imgs_test_id.npy')

# %% [markdown]
# Visualize some of the test images.

# %%
plot_n((test_imgs,), ('US image',), n=4, width=6, height=12)

# %%
imgs_test = preprocess(test_imgs, img_rows=resized_img_rows, img_cols=resized_img_cols)
imgs_test = imgs_test.astype('float32')
imgs_test -= mean_train
imgs_test /= std_train

print('Images:')
print('Test data: {}'.format(test_imgs.shape))
print('Preprocessed test data: {}'.format(imgs_test.shape))
# Out:
# /home/alexej/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Images:
# Test data: (5508, 420, 580)
# Preprocessed test data: (5508, 80, 112, 1)

# %%
model.load_weights('weights_2.h5')

imgs_mask_test = model.predict(imgs_test, verbose=1)
#np.save('imgs_mask_test.npy', imgs_mask_test)
# Out:
# 5508/5508 [==============================] - 3s 616us/step

# %% [markdown]
# Let's look at some of the predicted masks.

# %%
plot_n((imgs_test, imgs_mask_test), ('US image', 'Predicted mask'),
       n=10, width=10, height=42)

# %% [markdown]
# Since the input to the U-net was resized, we need to scale the predicted masks back to the original size for the submission to kaggle leaderboard.

# %%
image_rows = 420
image_cols = 580

from itertools import chain
    
def prep(img):
    img = img.astype('float32')
    img = (img > 0.5).astype(np.uint8)  # threshold
    img = resize(img, (image_rows, image_cols), preserve_range=True)
    return img


def run_length_enc(label):
    x = label.transpose().flatten()
    y = np.where(x > 0)[0]
    if len(y) < 10:  # consider as empty
        return ''
    z = np.where(np.diff(y) > 1)[0]
    start = np.insert(y[z+1], 0, y[0])
    end = np.append(y[z], y[-1])
    length = end - start
    res = [[s+1, l+1] for s, l in zip(list(start), list(length))]
    res = list(chain.from_iterable(res))
    return ' '.join([str(r) for r in res])

# %% [markdown]
# Write a Kaggle submission file.

# %%
#imgs_mask_test = np.load('imgs_mask_test.npy')
argsort = np.argsort(test_imgs_id)
test_imgs_id = test_imgs_id[argsort]
imgs_mask_test = imgs_mask_test[argsort]

total = imgs_mask_test.shape[0]
ids = []
rles = []
for i in tqdm_notebook(range(total)):
    img = imgs_mask_test[i, :, :, 0]
    img = prep(img)
    rle = run_length_enc(img)

    rles.append(rle)
    ids.append(test_imgs_id[i])

first_row = 'img,pixels'
file_name = 'submission.csv'

with open(file_name, 'w+') as f:
    f.write(first_row + '\n')
    for i in tqdm_notebook(range(total)):
        s = str(ids[i]) + ',' + rles[i]
        f.write(s + '\n')
# Out:
# ...
# /home/alexej/tensorflow/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# ...
